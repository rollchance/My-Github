# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/ColaIP/Images (1)/abcdef.bmp')

RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gImg.shape)
cv2_imshow(gImg)
#plt.imshow(gImg, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-070a95ca2cc7> in <cell line: 3>()
#       1 img = cv2.imread('/content/gdrive/My Drive/ColaIP/Images (1)/abcdef.bmp')
#       2
# ----> 3 RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       4
#       5 gImg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
heigh, width = gImg.shape[:2]
print(heigh, width)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-61a929834c80> in <cell line: 1>()
# ----> 1 heigh, width = gImg.shape[:2]
#       2 print(heigh, width)
#
# NameError: name 'gImg' is not defined

# %%
M = np.float32([[1,0,100],[0,1,100]])
outImg = cv2.wrapAffine(gImg, M, (width, height))
cv2_imshow(outImg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-61474b56caf5> in <cell line: 2>()
#       1 M = np.float32([[1,0,100],[0,1,100]])
# ----> 2 outImg = cv2.wrapAffine(gImg, M, (width, height))
#       3 cv2_imshow(outImg)
#
# AttributeError: module 'cv2' has no attribute 'wrapAffine'

# %%
M = cv2.getRotationMatrix2D(((width-1)2.0, (height-1)/2.0), -45, 1)
#M = cv2.getRotationMatrix2D((0, 0), -45, 1)
print(M)
print(M.shape)
outImg = cv2.wrapAffine(gImg, M, (width, height))
cv2_imshow(outImg)
# Out:
#   File "<ipython-input-28-931e68ede213>", line 1
#     M = cv2.getRotationMatrix2D(((width-1)2.0, (height-1)/2.0), -45, 1)
#                                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
M = cv2.getRotationMatrix2D((0, 0), -45, 1)
outImg1 = cv2.wrapAffine(gImg, M, (width, height))
cv2_imshow(outImg1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-96bc4d233893> in <cell line: 2>()
#       1 M = cv2.getRotationMatrix2D((0, 0), -45, 1)
# ----> 2 outImg1 = cv2.wrapAffine(gImg, M, (width, height))
#       3 cv2_imshow(outImg1)
#
# AttributeError: module 'cv2' has no attribute 'wrapAffine'

# %%
M = np.float32([[1,0,20],[0,1,20]])
outImg = cv2.wrapAffine(outImg1, M, (width, height))
cv2_imshow(outImg2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-39644bb04a25> in <cell line: 2>()
#       1 M = np.float32([[1,0,20],[0,1,20]])
# ----> 2 outImg = cv2.wrapAffine(outImg1, M, (width, height))
#       3 cv2_imshow(outImg2)
#
# AttributeError: module 'cv2' has no attribute 'wrapAffine'

# %%
M1 = cv2.getRotationMatrix2D((0, 0), -45, 1)
M2 = np.float32([[M1[0,0],M1[0,1],M1[0,2],M1[1,0],M1[1,1],M1[1,2],[0,0,1]])
M3 = np.float32([[1,0,20],[0,1,20]], [0,0,1]])
M4 = np.dot(M3, M2)
# Out:
#   File "<ipython-input-23-6c360c3f42b8>", line 2
#     M2 = np.float32([[M1[0,0],M1[0,1],M1[0,2],M1[1,0],M1[1,1],M1[1,2],[0,0,1]])
#                                                                               ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
M5 = np.float32([[M4[0,0],M4[0,1],M4[0,2],[M4[1,0],M4[1,1],M4[1,2]]])
outImg3 = cv2.wrapAffine(outImg1, M5, (width, height))
cv2_imshow(outImg3)
# Out:
#   File "<ipython-input-27-aeb494b3f3d5>", line 1
#     M5 = np.float32([[M4[0,0],M4[0,1],M4[0,2],[M4[1,0],M4[1,1],M4[1,2]]])
#                                                                         ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
M = np.float32([[1,0,20],[0,1,20]])
outImg2 = cv2.wrapAffine(outImg1, M, (width, height))
cv2_imshow(outImg2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-abd567748303> in <cell line: 2>()
#       1 M = np.float32([[1,0,20],[0,1,20]])
# ----> 2 outImg2 = cv2.wrapAffine(outImg1, M, (width, height))
#       3 cv2_imshow(outImg2)
#
# AttributeError: module 'cv2' has no attribute 'wrapAffine'

# %%
M = np.float32([[1,0, -(width-1)/2.0],[0,1,-(height-1)/2.0]])
out1 = cv2.warpAffine(gImg, M, (width, height))
cv2_imshow(out1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-aaf2e2a96c9e> in <cell line: 1>()
# ----> 1 M = np.float32([[1,0, -(width-1)/2.0],[0,1,-(height-1)/2.0]])
#       2 out1 = cv2.warpAffine(gImg, M, (width, height))
#       3 cv2_imshow(out1)
#
# NameError: name 'width' is not defined

# %%
M = cv2.getRotationMatrix2D((0, 0), -45, 1)
out2 = cv2.wrapAffine(out1, M, (width, height))
cv2_imshow(outImg1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-694e020b59d1> in <cell line: 2>()
#       1 M = cv2.getRotationMatrix2D((0, 0), -45, 1)
# ----> 2 out2 = cv2.wrapAffine(out1, M, (width, height))
#       3 cv2_imshow(outImg1)
#
# AttributeError: module 'cv2' has no attribute 'wrapAffine'

# %%
M = np.float32([[1,0, (width-1)/2.0],[0,1,(height-1)/2.0]])
out3 = cv2.warpAffine(out2, M, (width, height))
cv2_imshow(out1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-4cbcd3d42a27> in <cell line: 1>()
# ----> 1 M = np.float32([[1,0, (width-1)/2.0],[0,1,(height-1)/2.0]])
#       2 out3 = cv2.warpAffine(out2, M, (width, height))
#       3 cv2_imshow(out1)
#
# NameError: name 'width' is not defined

# %%
M1 = cv2.getRotationMatrix2D((0, 0), -45, 1)
M2 = np.float32([[M1[0,0],M1[0,1],M1[0,2],M1[1,0],M1[1,1],M1[1,2],[0,0,1]])
M3 = np.float32([[1,0, -(width-1)/2.0],[0,1,-(height-1)/2.0]],[0,0,1]])
M4 = np.float32([[1,0, (width-1)/2.0],[0,1,(height-1)/2.0]],[0,0,1]])
M5 = np.dot(M2, M3)
M5 = np.dot(M4, M5)
# Out:
#   File "<ipython-input-34-eb897e24c1a0>", line 2
#     M2 = np.float32([[M1[0,0],M1[0,1],M1[0,2],M1[1,0],M1[1,1],M1[1,2],[0,0,1]])
#                                                                               ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
M6 = np.float32([[M5[0,0],M5[0,1],M5[0,2]],[M5[1,0],M5[1,1],M5[1,2]]])
outImg4 = cv2.warpAffine(gImg, M6, (width, height))
cv2_imshow(outImg4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-28d484348d34> in <cell line: 1>()
# ----> 1 M6 = np.float32([[M5[0,0],M5[0,1],M5[0,2]],[M5[1,0],M5[1,1],M5[1,2]]])
#       2 outImg4 = cv2.warpAffine(gImg, M6, (width, height))
#       3 cv2_imshow(outImg4)
#
# NameError: name 'M5' is not defined
