# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/ColaIP/Images (1)/abcdef.bmp')

RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gImg.shape)
cv2_imshow(gImg)
#plt.imshow(gImg, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-070a95ca2cc7> in <cell line: 3>()
#       1 img = cv2.imread('/content/gdrive/My Drive/ColaIP/Images (1)/abcdef.bmp')
#       2
# ----> 3 RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       4
#       5 gImg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
#outImg = cv2.resize(gImg, None, fx = 0.5, fy = 0.5, interpolation = cv2.INTER_NEAREST)
#outImg = cv2.resize(gImg, None, fx = 0.3, fy = 0.3, interpolation = cv2.INTER_LINEAR)
outImg = cv2.resize(gImg, None, fx = 0.3, fy = 0.3, interpolation = cv2.INTER_CUBIC)

cv2_imshow(outImg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cdcc9180b8c8> in <cell line: 3>()
#       1 #outImg = cv2.resize(gImg, None, fx = 0.5, fy = 0.5, interpolation = cv2.INTER_NEAREST)
#       2 #outImg = cv2.resize(gImg, None, fx = 0.3, fy = 0.3, interpolation = cv2.INTER_LINEAR)
# ----> 3 outImg = cv2.resize(gImg, None, fx = 0.3, fy = 0.3, interpolation = cv2.INTER_CUBIC)
#       4
#       5 cv2_imshow(outImg)
#
# NameError: name 'gImg' is not defined

# %%
blurImg = cv2.GaussianBlur(gImg, (3,3), 1)
#outImg = cv2.resize(blurgImg, None, fx = 0.5, fy = 0.5, interpolation = cv2.INTER_NEAREST)
outImg = cv2.resize(blurgImg, None, fx = 0.3, fy = 0.3, interpolation = cv2.INTER_LINEAR)
#outImg = cv2.resize(blurgImg, None, fx = 0.3, fy = 0.3, interpolation = cv2.INTER_CUBIC)

cv2_imshow(outImg)
