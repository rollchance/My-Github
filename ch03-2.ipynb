# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/ColablP/Images/peppers.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gImg1.shape)
#plt.imshow(gImg1, cmap='gray')
cv2_imshow(gImg2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-747503bd20f0> in <cell line: 2>()
#       1 img = cv2.imread('/content/gdrive/My Drive/ColablP/Images/peppers.jpg')
# ----> 2 RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       3
#       4 gImg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
#       5 print(gImg1.shape)
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
gPlus = np.zeros((gImg.shape[0], gImg.shape[1]), dtype=np.ubyte)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-78ee5341d08a> in <cell line: 1>()
# ----> 1 gPlus = np.zeros((gImg.shape[0], gImg.shape[1]), dtype=np.ubyte)
#
# NameError: name 'gImg' is not defined

# %%
weight = 0.7

for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    plusVal = np.int32(gImg1[h,w])*weight + np.int32(gImg2[h,w])
    if(plusVal > 255):
      plusVal = 255
    gPlus[h,w] = plusVal

cv2_imshow(gPlus)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-65ff1f603e52> in <cell line: 3>()
#       1 weight = 0.7
#       2
# ----> 3 for h in range(gImg1.shape[0]):
#       4   for w in range(gImg1.shape[1]):
#       5     plusVal = np.int32(gImg1[h,w])*weight + np.int32(gImg2[h,w])
#
# NameError: name 'gImg1' is not defined
