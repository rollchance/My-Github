# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/Images(1)/abcdef.bmp')

RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gImg.shape)
cv2_imshow(gImg)
#plt.imshow(gImg, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-6512db962439> in <cell line: 3>()
#       1 img = cv2.imread('/content/gdrive/My Drive/Images(1)/abcdef.bmp')
#       2
# ----> 3 RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       4
#       5 gImg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
gx = np.array([[-1, 0], [0,1]], dtype = int)
gx = np.array([[0, 1], [-1,0]], dtype = int)

# %%
x = cv2.filter2D(gImg, -1, gx)
y = cv2.filter2D(gImg, -1, gy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-35530312e448> in <cell line: 1>()
# ----> 1 x = cv2.filter2D(gImg, -1, gx)
#       2 y = cv2.filter2D(gImg, -1, gy)
#
# NameError: name 'gImg' is not defined

# %%
absX = cv2.convertScaleAbs(x)
absY = cv2.convertScaleAbs(y)
outImg = cv2.addWeighted(absX, 0.5, absY, 0.5, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f1f5eabed18e> in <cell line: 1>()
# ----> 1 absX = cv2.convertScaleAbs(x)
#       2 absY = cv2.convertScaleAbs(y)
#       3 outImg = cv2.addWeighted(absX, 0.5, absY, 0.5, 0)
#
# NameError: name 'x' is not defined

# %%
#outImg = outImg * 10
cv2_imshow(outImg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5b8383454051> in <cell line: 2>()
#       1 #outImg = outImg * 10
# ----> 2 cv2_imshow(outImg)
#
# NameError: name 'outImg' is not defined

# %%
gBin = np.zeros((gImg.shape[0], gImg.shape[1]), dtype = np.ubyte)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-87cd060c4e03> in <cell line: 1>()
# ----> 1 gBin = np.zeros((gImg.shape[0], gImg.shape[1]), dtype = np.ubyte)
#
# NameError: name 'gImg' is not defined

# %%
threshold = 40

for h in range(gImg.shape[0]):
  for w in range(gImg.shape[1]):
    if(outImg[h, w] > threshold):
      outImg[h,w] = 255

cv2_imshow(gBin)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d585ccab38a8> in <cell line: 3>()
#       1 threshold = 40
#       2
# ----> 3 for h in range(gImg.shape[0]):
#       4   for w in range(gImg.shape[1]):
#       5     if(outImg[h, w] > threshold):
#
# NameError: name 'gImg' is not defined

# %%
cannyImg = cv2.Canny(gImg, 20, 200)
cv2_imshow(cannyImg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5199c5c0c6fc> in <cell line: 1>()
# ----> 1 cannyImg = cv2.Canny(gImg, 20, 200)
#       2 cv2_imshow(cannyImg)
#
# NameError: name 'gImg' is not defined

# %%
blurImg = cv2.GaussianBlur(gImg, (5,5), 1.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8b88d06edfe8> in <cell line: 1>()
# ----> 1 blurImg = cv2.GaussianBlur(gImg, (5,5), 1.4)
#
# NameError: name 'gImg' is not defined

# %%
x = cv2.filter2D(blurImg, -1, gx)
y = cv2.filter2D(blurImg, -1, gy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b6f177719d37> in <cell line: 1>()
# ----> 1 x = cv2.filter2D(blurImg, -1, gx)
#       2 y = cv2.filter2D(blurImg, -1, gy)
#
# NameError: name 'blurImg' is not defined

# %%
absX = cv2.convertScaleAbs(x)
absY = cv2.convertScaleAbs(y)
cannyOutImg = cv2.addWeighted(absX, 0.5, absY, 0.5, 0)
cv2_imshow(cannyOutImg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-4dc8e22d2c2b> in <cell line: 1>()
# ----> 1 absX = cv2.convertScaleAbs(x)
#       2 absY = cv2.convertScaleAbs(y)
#       3 cannyOutImg = cv2.addWeighted(absX, 0.5, absY, 0.5, 0)
#       4 cv2_imshow(cannyOutImg)
#
# NameError: name 'x' is not defined

# %%
cannyDirection = np.arctan2(y, x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f7c8aa915ebd> in <cell line: 1>()
# ----> 1 cannyDirection = np.arctan2(y, x)
#
# NameError: name 'y' is not defined
