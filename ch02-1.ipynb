# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/ColablP/ch01/.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-549da7981c52> in <cell line: 2>()
#       1 img = cv2.imread('/content/gdrive/My Drive/ColablP/ch01/이재용.jpg')
# ----> 2 RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       3 plt.imshow(RGB_img)
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
print(RGB_img.shape);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-bcd311d112d6> in <cell line: 1>()
# ----> 1 print(RGB_img.shape);
#
# NameError: name 'RGB_img' is not defined

# %%
 cv2.split(RGB_img);
