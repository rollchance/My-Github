# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/Images(1)/abcdef.bmp')

RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gImg.shape)
cv2_imshow(gImg)
#plt.imshow(gImg, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-6512db962439> in <cell line: 3>()
#       1 img = cv2.imread('/content/gdrive/My Drive/Images(1)/abcdef.bmp')
#       2
# ----> 3 RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       4
#       5 gImg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
kernel3 = np.ones((3,3),np.float32)/9
kernel5 = np.ones((5,5),np.float32)/25

# %%
outImg5 = cv2.filter2D(gImg,-1,kernel5)
outImg3 = cv2.filter2D(gImg,-1,kernel3)
cv2_imshow(outImg3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-525db8a416a6> in <cell line: 1>()
# ----> 1 outImg5 = cv2.filter2D(gImg,-1,kernel5)
#       2 outImg3 = cv2.filter2D(gImg,-1,kernel3)
#       3 cv2_imshow(outImg3)
#
# NameError: name 'gImg' is not defined

# %%
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] = -1/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9

# %%
outImg33 = cv2.filter2D(outImg3,-1,kernel3)
cv2_imshow(outImg3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5b43093c2d9a> in <cell line: 1>()
# ----> 1 outImg33 = cv2.filter2D(outImg3,-1,kernel3)
#       2 cv2_imshow(outImg3)
#
# NameError: name 'outImg3' is not defined

# %%
outImg33 = cv2.filter2D(outImg3,-1,kernel3)
cv2_imshow(outImg3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5b43093c2d9a> in <cell line: 1>()
# ----> 1 outImg33 = cv2.filter2D(outImg3,-1,kernel3)
#       2 cv2_imshow(outImg3)
#
# NameError: name 'outImg3' is not defined

# %%
kernel3[0][0] = 0
kernel3[0][1] = 0
kernel3[0][2] = 0
kernel3[1][0] = 0
kernel3[1][1] = 0
kernel3[1][2] = 0
kernel3[2][0] = 0
kernel3[2][1] = 0
kernel3[2][2] = 0

# %%
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] = -1/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9
